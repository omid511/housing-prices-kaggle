# %% [markdown]
# # Environment Verification
# Run this cell to verify that all required packages are installed.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import lightgbm as lgb
import sweetviz as sv

print(f"Pandas version: {pd.__version__}")
print(f"LightGBM version: {lgb.__version__}")
print(f"Seaborn version: {sns.__version__}")
print("All packages imported successfully!")

# %%
# Check if data is available (after environment setup)
import os
if os.path.exists('data/train.csv'):
    print("Data directory found and train.csv exists.")
    df = pd.read_csv('data/train.csv')
    print(f"Loaded training data with shape: {df.shape}")
else:
    print("Data directory not found. It should be created automatically by the postCreateCommand.")
